# %% [markdown]
# # Data Mining Project
#
# The goal of this task is to explore the Yelp data set to get a sense about what the data look like and their characteristics. You can think about the goal as being to answer questions such as:
# 1. What are the major topics in the reviews? Are they different in the positive and negative reviews? Are they different for different cuisines?
# 2. What does the distribution of the number of reviews over other variables (e.g., cuisine, location) look like?
# 3. What does the distribution of ratings look like?
#
# As with any project, we start with a little...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd

from string import punctuation    #Dis for cleaning

# %% [markdown]
# First we read in the data with a little help from pandas

# %%
reviews_df = pd.read_json("yelp_academic_dataset_review.json", lines=True)
reviews_df.head()
# Out:
#               business_id       date               review_id  stars  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA 2007-05-17  15SdjuK7DmYqUAj6rjGowg      5
# 1  vcNAWiLM4dR7D2nwwJ7nCA 2010-03-22  RF6UnRTtG7tWMcrO2GEoAg      2
# 2  vcNAWiLM4dR7D2nwwJ7nCA 2012-02-14  -TsVN230RCkLYKBeLsuz7A      4
# 3  vcNAWiLM4dR7D2nwwJ7nCA 2012-03-02  dNocEAyUucjT371NNND41Q      4
# 4  vcNAWiLM4dR7D2nwwJ7nCA 2012-05-15  ebcN2aqmNUuYNoyvQErgnA      4
#
#                                                 text    type  \
# 0  dr. goldberg offers everything i look for in a...  review
# 1  Unfortunately, the frustration of being Dr. Go...  review
# 2  Dr. Goldberg has been my doctor for years and ...  review
# 3  Been going to Dr. Goldberg for over 10 years. ...  review
# 4  Got a letter in the mail last week that said D...  review
#
#                   user_id                                 votes
# 0  Xqd0DzHaiyRqVH3WRG7hzg  {'funny': 0, 'useful': 2, 'cool': 1}
# 1  H1kH6QZV7Le4zqTRNxoZow  {'funny': 0, 'useful': 2, 'cool': 0}
# 2  zvJCcrpm2yOZrxKffwGQLA  {'funny': 0, 'useful': 1, 'cool': 1}
# 3  KBLW4wJA_fwoWmMhiHRVOA  {'funny': 0, 'useful': 0, 'cool': 0}
# 4  zvJCcrpm2yOZrxKffwGQLA  {'funny': 0, 'useful': 2, 'cool': 1}

# %%
reviews_df.shape
# Out:
# (1125458, 8)

# %% [markdown]
# We have a problem: so much reviews! I want to take a subset of the data. Types of businesses seems like a good place to go. Let's see how many types of businesses there are.

# %%
reviews_df.business_id.nunique()
# Out:
# 41958

# %% [markdown]
# That's a lot of businesses. Since food is what gets me out of bed everyday, I only want to look at restaurants. How to do that? We need to read in the business dataset and see what business_ids match with restaurants. Let's go.

# %%
business_df = pd.read_json("yelp_academic_dataset_business.json", lines=True)
business_df.shape
# Out:
# (42153, 15)

# %% [markdown]
# Interestingly bigger than the reviews number. That suggests that not all places have reviews, which is a reasonable thing. Smaller than the other dataset but still huge! Let's take a sneak peak.

# %%
business_df.head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %% [markdown]
# We can see that the column that we want is the categories column. We see that its an array of categories, and so we are looking for the word Restaurants in that column to make a new dataframe. I am cheating and converting the column to a string because dealing with that list was too much.

# %%
business_df['categories'] = business_df['categories'].apply(', '.join)
restaurants_df = business_df[business_df['categories'].str.contains("Restaurants")]
restaurants_df.shape
# Out:
# (14303, 15)

# %%
restaurants = list(restaurants_df['business_id'])
restaurants[0:10]
# Out:
# ['JwUE5GmEO-sH1FuwJgKBlQ',
#  'uGykseHzyS5xAMWoN6YUqA',
#  'LRKJF43s9-3jG9Lgx4zODg',
#  'RgDg-k9S5YD_BaxMckifkg',
#  'rdAdANPNOcvUtoFgcaY9KA',
#  '_wZTYYL7cutanzAnJUTGMA',
#  'zOc8lbjViUZajbY7M0aUCQ',
#  'UgjVZTSOaYoEvws_lAP_Dw',
#  'SKLw05kEIlZcpTD5pqma8Q',
#  '77ESrCo7hQ96VpCWWdvoxg']

# %% [markdown]
# Now I want to only have the businesses that match restaurant ids in the main df

# %%
restaurant_reviews_df = reviews_df.loc[reviews_df['business_id'].isin(restaurants)]
restaurant_reviews_df.shape
# Out:
# (706646, 8)

# %% [markdown]
# Still pretty huge. Now we'll cut it down based on the number of reviews. We'll keep places that have at least 5 reviews because that seems like a reasonable number for the public to judge a place. Let's see what we are dealing with.

# %%
review_counts = dict(restaurant_reviews_df.business_id.value_counts())
review_counts
# Out:
# {'4bEjOyTaDG24SY5TxsaUNQ': 3695,
#  '2e2e7WgqU1BnpxmQL5jbfw': 3263,
#  'zt1TpTuJ6y9n551sw9TaEg': 3011,
#  'YNQgak-ZLtYJQxlDwN-qIg': 2494,
#  'Xhg93cMdemu5pAMkDoEdtQ': 2399,
#  'tFU2Js_nbIZOrnKfYJYBBg': 2203,
#  'CZjcFdvJhksq9dy58NVEzw': 2122,
#  'sIyHTizqAiGu12XMLX3N3g': 2090,
#  'xfwRO04KbAPw_zRotCfWQQ': 2027,
#  'DO3Gk17RyJVW7zYMCtYPnw': 1819,
#  'xyTJYlbE_MLouK6rCou6zg': 1690,
#  'aGbjLWzcrnEx2ZmMCFm3EA': 1671,
#  'lliksv-tglfUz1T3B3vgvA': 1647,
#  'eq6lQI039SBLC6sHm3idGA': 1607,
#  'QbmcCE_cLq4WO8ZMKImaLw': 1582,
#  'PXviRcHR1mqdH4vRc2LEAQ': 1530,
#  'BqrTtox0JbG-P_DKBB5bBw': 1358,
#  'jOuERtVf7QePnK9ZcdH5XA': 1340,
#  'HbUQ_3dlm3uCacmhTEMnuA': 1297,
#  '8buIr1zBCO7OEcAQSZko7w': 1237,
#  'vxxMqBaAHuWdx4impsLSSA': 1205,
#  'FV16IeXJp2W6pnghTz2FAw': 1196,
#  'rBPQuQgTcMtUq5-RYhY2uQ': 1191,
#  'VVeogjZya58oiTxK7qUjAQ': 1178,
#  'mDdqifuTrfXAOfxiLMGu5Q': 1110,
#  'SsTxjxo8qvqBMvan1rzNzg': 1083,
#  'JokKtdXU7zXHcr20Lrk29A': 1040,
#  'DjOxXobyGDwWt89q4z1twg': 1038,
#  'NsnZ5GhagXBKrCOelxVQxw': 1037,
#  'tqu42L0qXzkvYKSruOz0IA': 1031,
#  'EWMwV5V9BxNs_U6nNVMeqw': 1020,
#  'YrIfgzLj0DPStJ1ESAS_Qg': 1011,
#  '4UVhuOLaMm2-34SrW8y-ag': 973,
#  'SLyacGZuMUKqrQJEooSkjw': 966,
#  'V1nEpIRmEa1768oj_tuxeQ': 964,
#  'ngNvH4sxnH9aMukTZ67R_Q': 962,
#  '5GKbGn9-fAgQ0njSh3OJ8A': 941,
#  'IRYj1b1-mlXqABVsl9SoqQ': 925,
#  'zTCCbg7mGslxACL5KlAPIQ': 880,
#  'YacTpiq0ZptFcXD7I-kdGA': 879,
#  'SDwYQ6eSu1htn8vHWv128g': 862,
#  'KjymOs12Mpy0Kd54b7T9MA': 859,
#  'WNy1uzcmm_UHmTyR--o5IA': 855,
#  'eLPld7Q17XxlclFGzZQX5g': 819,
#  'LLDGTT7FExklkQvHebEjRg': 813,
#  'HyfFenprdpIA4rmKu6DW3g': 813,
#  'Pz7SWZQhxL6ZbhL9jE2NTA': 802,
#  'AeKTQBtPRDHLAFL9bzbUnA': 798,
#  'H_SuH7uLiYahDMbNBB9kog': 795,
#  '-sC66z4SO3tR7nFCjfQwuQ': 795,
#  'BqD7X5CHXnJ14YbBBlLx1w': 782,
#  '1yx2zLskVTe5WQdYjL2Apw': 752,
#  'vSf0pqvaLp5sVSjJPeOqqQ': 745,
#  'Z0kyK8wCBNGkkUT9UrMWcg': 743,
#  '3fV9sL5LklD9ZSeONKmjkw': 740,
#  'QnAzW6KMSciUcuJ20oI3Bw': 736,
#  'gGeVLZ9j_wAYKbaqgnKSJA': 730,
#  'YKOvlBNkF4KpUP9q7x862w': 725,
#  'ryvMJK6AlbU35HKrlFT61w': 722,
#  'ASOiJ8MmbBTgK2D1_MQrqg': 719,
#  'uKSX1n1RoAzGq4bV8GPHVg': 717,
#  'MuIXnv7Oq7X3-4aEsp9dDA': 704,
#  '3MmHmJXr8Ltk_Z5EGE4KUw': 700,
#  'aRkYtXfmEKYG-eTDf_qUsw': 693,
#  'ntN85eu27C04nwyPa8IHtw': 691,
#  'ES-j5yNTgmgbL4He0h6otA': 691,
#  'BW1JCE3Qj4uIokg7kLUL7w': 688,
#  'rZbHg4ACfN3iShdsT47WKQ': 685,
#  'iXA8Y2bzvZo8MjALfZxrIg': 678,
#  '3oZcTGb_oDHGwZFiP-7kxQ': 673,
#  'N50HceZf1595UtU867u4uQ': 672,
#  'cMvN1j-LK64zqmT4vnl8NA': 670,
#  '_FXql6eVhbM923RdCi94SA': 664,
#  '50nln4YPr0QDo_v1uBmHfg': 664,
#  'K8pM6qQdYu5h6buRE1-_sw': 660,
#  'Q_Rwcv9APBLggk2KAsBEvg': 657,
#  'pwpl-rxwNRQdgqFz_-qMPg': 650,
#  'KJnVuzpveyDrHARVNZaYVg': 642,
#  'xNcqwYAUeVOhe3KNC4Xjaw': 641,
#  'naLrErBuJr9IWd6_rv6-XQ': 640,
#  'RhbOa-Ft3sZB4B_1j5LfyA': 635,
#  'KcSJUq1kwO8awZRMS6Q49g': 634,
#  'XDYnLQC8ViZejuCDp4eCwg': 633,
#  'q_DrPmiLrHEpR_SQvQXELQ': 626,
#  'LCeF1wK5OqP3PPEVBa5Xfw': 624,
#  'lPh02W25cOrAz57UbTpbFQ': 614,
#  'kwEQ3uY9Jwmknb5kNg3UlA': 614,
#  'Zx8_4zKdDBSO3qGrkukBIA': 612,
#  'j_pce4pG9krrBeYwUni8Pg': 611,
#  'ZP6qFq7LUh6Tr7WHPoOW6g': 609,
#  'xY1sPHTA2RGVFlh5tZhs9g': 608,
#  'c1yGkETheht_1vjda7G5sA': 606,
#  '53YGfwmbW73JhFiemNeyzQ': 603,
#  'QJlab4DqvBRJPUfg7Vn5ZQ': 594,
#  'BQjGE1Z3nk253XzIZqt8Gg': 590,
#  'L9UYbtAUOcfTgZFimehlXw': 583,
#  '8zL3V6rmFKBess3bxPLAoQ': 580,
#  'qjmCVYkwP-HDa35jwYucbQ': 577,
#  '1U1GRksKXF7q8FKcW0e5VQ': 574,
#  'ggoYlZeQhATwb_yGSntfdw': 573,
#  'OFBJtqWGSx6n6CchtVmoRw': 569,
#  '-2n-OHbbwIv3SY8RP9bgTQ': 568,
#  'tn5SXZvWiT-uVsjXLGSrww': 565,
#  'nZgYNbl1XlZyyKlISMoG6w': 565,
#  'OiCxoAIoBvEWxf7p1qVVmA': 564,
#  'FHqwLwpLjUjeLP-IdG_o_w': 564,
#  '3n9mSKySEv3G03YjcU-YOQ': 564,
#  '4uGHPY-OpJN08CabtTAvNg': 558,
#  'cN6qpVw6RaSrSI-JGGF4Tw': 551,
#  'vARjqeIkSNsazHltujiq4Q': 549,
#  'y6NFyThUU2wtTNa0rX7VrA': 548,
#  'Zf7fMSe7yuW727JyikdBsg': 546,
#  '8Pzdk19tA2bKlKDSgwWqoQ': 544,
#  't6SuvEq9PPVGzNv5bJzDtw': 541,
#  'QRXv7Jvq_SuiiT_SKvbdig': 540,
#  'yJDSMugu_Pom3pJE8MRrJA': 538,
#  'dVAurLD1bBIi9IvuMFoL5g': 535,
#  'R8VwdLyvsp9iybNqRvm94g': 534,
#  'UEUQS4z7s-DRzQjky92KYw': 533,
#  '1NZLxU5WvB5roPFzneAlLw': 532,
#  'rfDTJLEwZZ2EGOZiTDdqQA': 529,
#  'uEJQSIjWui-TDWXaGlcqyQ': 527,
#  'J4qLz0nGzCTMf6-kf_SiQg': 523,
#  '05fTEsjUPVo5jks8PpNKCQ': 518,
#  'Xq9tkiHhyN_aBFswFeGLvA': 518,
#  'yD1dRYi7USzhYVKiqZ7JVg': 513,
#  'FURgKkRFtMK5yKbjYZVVwA': 513,
#  'IVc23uY-36WUNYoIbz42Fg': 505,
#  '9Bnc9YP0n5cR57xkP6fQmQ': 503,
#  'I4bSn5gXsHuSPu7L-d_8nQ': 501,
#  'Yq8LiVymGA7vBpGCQuDfRw': 496,
#  'H6CJflwclNpttYrtsBMsVg': 490,
#  'uqisw8IXD5ZutU4MT2MQVw': 489,
#  'wfofFm3AqtyK_ujNQ893mQ': 483,
#  '5rDosv0aIBhLg81IMSnlyg': 482,
#  'bmNPNlCLDplWB55ic3Bixg': 479,
#  'Ensu96ecI0OReupNS2x7ig': 479,
#  '79EG9Pv0bxNTmBjTVCd4CQ': 479,
#  'b25jGkZerj2M4WAy95n1Tg': 478,
#  'rNahhyqDlouyDMHh57p3ug': 475,
#  '83DsSlg-swjLzmZnUzq2UA': 475,
#  '5VMajxduxfLPSyQkVFKESg': 472,
#  'pPfQ73--Y_h5Or0aqDgEGA': 471,
#  'Gn7bMxhZgY0bivsthvJWJQ': 469,
#  'zp713qNhx8d9KCJJnrw1xA': 464,
#  'tcphcsPONrP82kUyvcELoA': 463,
#  'e8FMAuTswDueAlLsNyLhcA': 460,
#  'Fh6OndE60vzvyhCX1Wg7Aw': 457,
#  '25fxw_jOqZtJwl18cCarIA': 457,
#  'VkPzsY09S4zO0XqhA1mc6Q': 456,
#  'Gvw2ewUbqq7PWkxKwjqifA': 455,
#  'AkOruz5CrCxUmXe1p_WoRg': 455,
#  'FV0BkoGOd3Yu_eJnXY15ZA': 453,
#  '05tazaFQt1EnQ_Gk_1AFyg': 453,
#  'APe_0I6DqbNQonSlEkMSEQ': 453,
#  'v7OwbHgNgy_VQ9eP5FjvUA': 452,
#  'ZHDf8TUICsB2peQ9AmXeFw': 452,
#  'wNsmt1hF1uv3YvbwXZMAoQ': 450,
#  '_VN5hYv1VgNIBgwxTQZ_1Q': 449,
#  'mxrXVZWc6PWk81gvOVNOUw': 442,
#  'NxsCqQCpofRx08m535JYIA': 438,
#  'Gq092IH6eZqhAXwtXcwc6A': 438,
#  'z3yFuLVrmH-3RJruPEMYKw': 438,
#  'YQvg0JCGRFUkb6reMMf3Iw': 438,
#  'E9ZsPtGovfEPHlMHkDdlQA': 437,
#  'OHsuvX4rmhnPvvRBb-QK7A': 434,
#  'V6BYjHM9SnXscfkln3hCdA': 431,
#  'c12WDNrP2wyQgbnEYDdxCw': 431,
#  'O-Xa9GCFWI65YiBD5Jw_hA': 425,
#  'bgTB6MgdVQssXhkNJ7qIfw': 424,
#  'M2SjLXsuAy5RNKwxaA5E1g': 422,
#  'Lq6CDJ2yHmMs4N7jscQhHQ': 421,
#  'nREHMbIzWdfWtOh4l1bT3g': 421,
#  'gkWEjZIVcrUerEzed6IKpg': 421,
#  'cp39VURFby4A6u9m2It8jg': 419,
#  'kgt13cwkP03NS8FJKgdLMw': 418,
#  '-5RN56jH78MV2oquLV_G8g': 417,
#  'pVH6ngKnMdJSpkFEw0XKlQ': 417,
#  'xheJf3qJLLf4-Ck8ay3GFg': 417,
#  'k8bSp5BfCNCKqTXcKALXtw': 416,
#  '2ceeU8e3nZjaPfGmLwh4kg': 416,
#  '_6gbnNRPIc-iM_0cBLPX1A': 415,
#  'YppzR-sn8y15dmUd1lLcfw': 414,
#  '9Y3aQAVITkEJYe5vLZr13w': 411,
#  '3w5gd4EuSc75UKYMJiNUPA': 410,
#  '7SO_rX1F6rQEl-5s3wZxgQ': 408,
#  'i3ogCoQD4MY_sR73GCk-BA': 407,
#  'FqzgT9Y-Yu7jiWdHnGW-kQ': 407,
#  '6imLt53br7SJ3av07jjH7w': 404,
#  'r0ZoytDjK4CY5ytFNjZLvw': 404,
#  '5FLRsYrT6w2VSDvQDhphXg': 403,
#  'PmPOuRvuN3CoNOi1nBj_TQ': 402,
#  '84bLhe1aibxNmogtqSO4rA': 401,
#  'Y-9dJvw-J2d9QKfuL7mKgA': 400,
#  'npfVfumxVAkQNYpY1fSvew': 400,
#  'Zh_y9AmSfWZpR2JB9wye-A': 400,
#  'Pgp3gbOQaJIdyjqC9AOz6g': 400,
#  'KwLfgeylp9d8zY3KacREiw': 399,
#  'N8cJk5s9yW3fLeJyHQeRAA': 399,
#  'bqYrEwL5xjqv0u8XAij--Q': 398,
#  'JsDZZ9S3qntzCfo5N_Ci6A': 396,
#  'UpMR63WZgIn8VDKnYpDwXA': 395,
#  'EKzMHI1tip8rC1-ZAy64yg': 395,
#  'XWvht_1ZLdK7EHJ3jo4q0g': 394,
#  'M-vOSYnyuaE2TsFJF0uMbQ': 393,
#  '1bJjWGYip-V2PGj4VIwbiQ': 393,
#  'cN6aBxe2mQvrQlzk26LyRQ': 390,
#  'fwcoLKfZYMH6nZbAaeD6sw': 389,
#  'zNzJkzZxPTeTbRIRfeU9_Q': 389,
#  '-4A5xmN21zi_TXnUESauUQ': 387,
#  'qLa_684GMvVfR4WNHshQSA': 385,
#  'JhupPnWfNlMJivnWB5druA': 384,
#  'blgSBn3CimrCHn2SuZvcZw': 383,
#  'rP76z9iDOFczywAiee-l7A': 381,
#  'c8Xamwyv5Tyi2VjjyQcwaw': 378,
#  'dcd3C1gWv-vVdQ9XYV8Ubw': 378,
#  'WhBxWYRj6rycigYqdXY9cA': 378,
#  'Lp-A-JNRUUH72uou5-pMtQ': 378,
#  'fkVBloMEFJG2HTgeCxeNDg': 378,
#  '6oRAC4uyJCsJl1X0WZpVSA': 377,
#  '07bUAD_qnrJAXvJou_ls4g': 376,
#  'pD7NzevYc6HhYu13wCxiiw': 376,
#  '23SJEjfyU5gxY2chAKhgcw': 376,
#  'z67yrh03lRSANrpPsRcTfw': 374,
#  'b5cEoKR8iQliq-yT2_O0LQ': 374,
#  'LnCbpxipUrA165zvfaePGw': 374,
#  'sbsFamEj5wDxNAjUKrMcSw': 372,
#  'xxOQ7h6s3InV8o8DOVHlMA': 370,
#  'OwBPjUz2o0J5K3DzcHkBtg': 370,
#  'xnRljkaR6zaVTpLYolQteg': 368,
#  'ZxmKA8b7njab1DNzCEU4Ow': 368,
#  'OE5nAmaSVaopeRS1Cs9Kuw': 367,
#  'V9euJerhCkh7PXKjtsE2rQ': 367,
#  'QozXMHqNzkVutP-FhcP30w': 367,
#  'jRfdz5voj40P6WS9L54caw': 365,
#  '5kRug3bEienrpovtPRVVwg': 362,
#  '3OB5gQqibKGTzx9R1w7wKQ': 362,
#  '_zrSQdISpB_qry9tb098rw': 362,
#  'LXrq0Fw6MCz70KMA928ldQ': 361,
#  'D_BMUHbZk67hzRcK3xQQmg': 361,
#  'G6mZKMiDqHDgH92IOg9QhQ': 360,
#  'kKcniirsMqUd_x0pZEGcWA': 360,
#  'ADTZPVMIYJN0jAvvHxcBMw': 358,
#  'a4cMKOjdVLTmJNhRl6-17g': 357,
#  'PPwJTT-eLjapipmyQSgi9A': 356,
#  '8HCC8NuJmdHnEg2XC00NPg': 356,
#  'jmgKs7CTqSWWwJnFnPIf4A': 356,
#  's1dex3Z3QoqiK7V-zXUgAw': 356,
#  'XHr5mXFgobOHoxbPJxmYdg': 355,
#  'pwF_phwjD1ZHsY1xC9H7mA': 355,
#  'k-D2NUfaUbuQzPaMXniXcA': 354,
#  '_fn0UIgqzCtxXcmHRi8FOw': 353,
#  'm9haUi2_1lHR2eAKBhKwDg': 348,
#  '-SNpLwJNup8N96yq7sBJyw': 348,
#  'MN0OLvP8i0SirMJ7AMuMzA': 347,
#  'GJp4zTQPPsCEkUitopGfAQ': 347,
#  '9BJ5h9X1krpXFjKj0a6wbg': 346,
#  'aYAlzKHwXQn6JNLweRnZjQ': 345,
#  '_tS0YfyPDxOXxrN4Kl2_HQ': 344,
#  '5IWu0xhlZEopvIz3w7o_3w': 344,
#  'iNT6pcUugoXsDlZgRTyhtw': 342,
#  'rMSje59v2QY82OBvE1zBuA': 341,
#  'tI3J5jomrBs--n7r92186g': 341,
#  'bCRrLdBLel3y73tA8w6C3Q': 339,
#  'vPnwX30Gn0oa4dVBL0W4Ww': 339,
#  'M6fjHpkL9IRI-nI0BattRw': 339,
#  'bzDs0u8I-z231QVdIQWkrA': 338,
#  'FUI-hWH_bpis7AKZTWenUQ': 337,
#  'vvur3WRgdgnhYoMUXMZZCA': 337,
#  '0i0PwU8lpj4evYKQogWxcA': 337,
#  'EUmfOpiQxJ5yaEMypI30gQ': 337,
#  'cmv6wUUe-H0xRiFEY0__iQ': 336,
#  '-AAig9FG0s8gYE4f8GfowQ': 335,
#  'PNThcRNEFI3azvfhvhd_KA': 334,
#  'PiV7phVMf7glDpH_J630Ow': 334,
#  'bGj9djLAHjNR55OXsIDrAg': 334,
#  '1nO6ffHEwZYFBzEsyw1w7w': 333,
#  'M3sHcgWd1gqw5c3L8QnAHQ': 333,
#  'ZNdsRbGeOfrYYPRl6AziCQ': 333,
#  '_45p8kOA__aNycVVe-n-KA': 332,
#  'QcTj9AgGJA0ifMHCCPNblg': 332,
#  'SMpL3z4FLF07bRA6-y22JQ': 331,
#  'JauLZ0TL3D3VIGtSnStzhA': 330,
#  'hfl62LX14YqNpG0g0Tj6_Q': 327,
#  'f6KGn2OyYk6LWEpnUEgerw': 327,
#  'Xsp9Dy4PQgAssCVk2-f73w': 326,
#  '4EhFsjWBSaSp_5TkkLp7LA': 326,
#  '41j3GB7M-Lwq284Pfb9zgw': 326,
#  'alWTl5MRC4VE2t9W1mNSIQ': 325,
#  'ieYiud3trM-9e7E8YUhK0g': 324,
#  'EolW2H_wkpYwWbBURN_4gQ': 324,
#  'eTbtfgUtfewdncgVf2CbWw': 323,
#  'eoDEx1GGQA0CBDhy2ql_Kw': 323,
#  '6IRoWd6N__OVMNQfvu1Ccw': 322,
#  'Bt7lGzIlPGc13iCXoc-TIw': 321,
#  'd52zg-S0o940WUCK-nNiKw': 321,
#  '_xmJB767rROtAy6XepMlkQ': 320,
#  'GGyHZtnAA5LBgouB-32ARA': 320,
#  'NVunai1t_GXQCAdDzFWJkQ': 320,
#  'jh7S78tc9oXCDjAjP_OrLw': 320,
#  'AaKlegu7gmOCD4rEESF76Q': 319,
#  'rDvz5jX65gpfONFu7er9Tw': 319,
#  'dxY1gl4cO4-rEFATCkFUIw': 319,
#  'BUpMSaHWxlWTgKTDIzz5Lw': 318,
#  '3l72FflaaeI0tWEAWN3-gQ': 318,
#  'WS1z1OAR0tRl4FsjdTGUFQ': 318,
#  'jJhNOhuGpIsJX5SEUFFWYQ': 316,
#  'VY_tvNUCCXGXQeSvJl757Q': 316,
#  '_Aq9R8FRoXq8HwC5qf80Xg': 315,
#  'HpaYCM_NCauI72LLXxC6SA': 315,
#  '4X_XAOeMw7AFkYhg3NINJA': 315,
#  'vaq5SJubaZjIoGhgkwxxUA': 315,
#  '0_LZEAYsexEZS-OFTjdjNQ': 313,
#  'wN_wAXWg8W94v04eqijy6g': 313,
#  'U6stLkJYMaro_4-3KI84_Q': 313,
#  'Az85N0Z4OKxOAzGdigi1nA': 312,
#  'QGkM1TvUrc1gmd1qkpnMJg': 311,
#  'bt9J3GgjArWCTfyoa3naEw': 311,
#  'rQ4z0EStSZE4acgkne6Hmg': 310,
#  'ss5gVggeSmAgMUeL65UvYw': 309,
#  'gu5Yj92bnXnxNyMdxO14VA': 309,
#  'LJxNzBCR383zSpe0jdU04Q': 309,
#  'sb4wU69LkCtC6Axqcd34WQ': 308,
#  '88CNSyeoKhGn1x0SHvz8Ig': 308,
#  'I1FRsqEw78xUR2gZBheHOQ': 308,
#  'mhQCxOiqp03qnhGRTtPduw': 307,
#  'luCSjoNQ9q_0QIjKKOy2pQ': 307,
#  'uHPXU5sWTZRILmMQbfWcJw': 307,
#  'OeinO4b26UcICbrLxoj3DQ': 306,
#  'yVQiGdxmnrkJDyQXv2maNA': 304,
#  'EC9WB-iVjd28B6R6KIZ8TA': 304,
#  'cBpJIOrVXotDI0XAZH_k0g': 303,
#  'PWG28q4JFOc8FiRBjnfCkA': 303,
#  'MXqmV0513hptrtjihDdf3Q': 302,
#  'SwmStS3zjj94aV8M7kYqLg': 302,
#  'RE3xkxkjmHQIARrLSIeerg': 302,
#  '_FBnbgbEwaZshbuoUoSBfA': 302,
#  'uiadM74nDbEPGeGQFghK0g': 301,
#  'sxRI0je6hAR-MeBDxdyhug': 300,
#  'eGevCRobYnA_HSj60sEWvQ': 299,
#  'r-a-Cn9hxdEnYTtVTB5bMQ': 299,
#  'IWwt0vm8lYbVoyGSPd2Z9A': 298,
#  'Y2BXS2OOrlMSYfS5xdjtmw': 297,
#  'DcrM4hwDcU2G6vuh2cnaYQ': 297,
#  'MhMFi7hae_KsaK8lHcg0iQ': 297,
#  'Lnohr9bpCbHNsomazXDg-w': 296,
#  'GRFunGSUZxXqNCZJrN8Oow': 295,
#  'pQSkGB3HIunzNn_vIRWUNQ': 295,
#  '5FE1Y9cZ-YOQA943nTi7cA': 294,
#  'EQxbEKkHxNvRT_-S5A-Gcw': 294,
#  '5fu41tfqTU_LONb95t1Dkg': 294,
#  '4AKcmN--0hbF0kX9pg8scg': 292,
#  'Hieqsu3u1peZ2I2jPwiKHw': 292,
#  'EmlgWjs1ZzZEpDjZCSPLmw': 292,
#  'LzNJLEIo4gh-X_rmDkNkNg': 292,
#  '90AXjqb4O-wrTHDKDoDUzg': 292,
#  'zMa6YoEekpABg1HZnnTZdg': 292,
#  'F8q_9PUl-Lwjj9xIRPArcg': 291,
#  '3AlN2XZ0I0F8650y2yjLWA': 290,
#  '0K634ehk41ZRc4kj3NTAEQ': 290,
#  'K8dQr_82-DMpDudEv8PDmw': 290,
#  '4uDW2Rp9eAPL5BUd5C5-bA': 289,
#  'Ky6490ndvfhU11eE7XcPLw': 289,
#  'PwxvN0SnAGPdqXdNEYVT3g': 289,
#  '5tYLVPc2PKnj6E62sY6QMg': 289,
#  '7QSYBp2-AOdyUJXEaLnbgA': 288,
#  'TzOTe6yecv99lZuKQ6fPfA': 288,
#  'IuAPYzf3NSyfyXYgT46YVA': 288,
#  'NYg-hgqjQvq5RDRcV7iv8A': 287,
#  'rGhbYmGvoqU7IVrmuNQi2g': 287,
#  'eIxSLxzIlfExI6vgAbn2JA': 287,
#  'TwxHMCcRdF_CQb_EZ6kPQQ': 287,
#  'UKKz4HdQC0aH9j5lLi4u8Q': 287,
#  'jtzhY-P4H6WSYpv5rWhxtw': 286,
#  'qXG8IlKuvy5k9fJ3y2gLgg': 286,
#  'olwuTiAEEFgSYefWUcZWbQ': 286,
#  'foDMwBRGJvKw791v0AT7OA': 286,
#  'bc-lE-wGVAsUrX-kJhtY-Q': 286,
#  '8t80-omyflkywRfu9LPh6g': 284,
#  'gUt-pPUpOVVhaCFC8-E4yQ': 284,
#  'L2J3JfjXZLnX1rLhWKthqA': 282,
#  'n_QAA70NrnGIsGjog3HF_Q': 282,
#  'Te5dA0G1-SWKGS8nuJp0Tg': 281,
#  'bQXzuRIQNKGxe0Py-CLDYA': 281,
#  'fSs0EdKmLJ7VULejtsi9CQ': 281,
#  'uR2aNW75R4oYs9w7aw-_kQ': 281,
#  '8Hn5X1AqgmSLHRG2KgBJBg': 280,
#  '7q1FpSXbE6XtLNg518pxDA': 280,
#  'kAXwEMkpcKMObw45QJGqnw': 280,
#  'aYEs_eXqnV8Ifj3Bp0bHwQ': 280,
#  '2f7TvlG5zcuMCHcQjxqS6A': 279,
#  'P5uC-zfGG6yqoQDUyqyAvg': 279,
#  'IyCwqORkMSmK4mAgAFHgnA': 278,
#  'udGgvy4TYdsdv13j1UzOIg': 277,
#  'co0vxQ8ecXiBy2sGDeHi8A': 276,
#  'wZwZcte4lcbu51NOzCjWbQ': 275,
#  'cwAd2nytPLKmABtLXsgpIw': 275,
#  'Ez2MFsVT5lJZ05yvK_0AXQ': 273,
#  'oCA2OZcd_Jo_ggVmUx3WVw': 273,
#  'OdKCcB8skRPVSk7yBGwang': 272,
#  'vW4G1hwiW6LkuhAfbeRfqg': 271,
#  'lqx--hrRwe0oK6WnFYNXlg': 270,
#  'h_WtRK_umSU8LCCmAeqbFA': 270,
#  'LuYZUc1MOG0pA146SCeXgA': 270,
#  'yYbd9P1KmlPSKmQxo68n_g': 270,
#  '2sn5BECdlYxqQlw1VODDoA': 270,
#  'fH5QqIDiwcgEnrSJYuiaaw': 269,
#  'd38y2fkW1542SaoSTvE1og': 269,
#  'j2KCZNlWnu-L4j0yJ3zAHA': 269,
#  'UBvTnbaRD3h_dD6oXWLCBA': 268,
#  'xV3OGVeNZyARob-L1SSTPQ': 268,
#  'oXKPSI-RUqOvmuSCh_DEQQ': 268,
#  'kFVapB4z_5VoOnYazF_ERA': 267,
#  'h6jfMpTZpNduLG0wE2tbaw': 267,
#  '33aOj9haiHsULCUmFOZ7uQ': 267,
#  '6qXQQOWdUZiJmWVqkWB-3w': 266,
#  'no_FXjscklz1SEzM_XnVgw': 266,
#  'ke3RFq3mHEAoJE_kkRNhiQ': 266,
#  'bOB11LVavtN9PWTNwR52Tw': 263,
#  'HDvCnqIf5twbMb5-eG1EJw': 263,
#  'cQMfAN2YVUcJn8wK2M_wGw': 263,
#  'JUATTlFUONx_er9_YRFDrw': 262,
#  'sBAueq0jUmlIH6vdgyP2aQ': 262,
#  'hsM6PF4Of6RMNcQV_c-FVQ': 261,
#  '8_HGHlHsNdCnTsLQYHteAw': 260,
#  'KPoTixdjoJxSqRSEApSAGg': 260,
#  '5FPU_0VSLtR2yY7IQzaH5g': 259,
#  'U87W6T9vjwWnp28Zjnn4pQ': 259,
#  'cRfn_vMQ9YExuKb378CwjQ': 258,
#  '4GQhbPvGU5r23YdVm8EmkQ': 257,
#  'MY0_6BAzQCu4sqXqwNEFfg': 257,
#  'Fb__zkvQX3W7u1A72h4wPw': 257,
#  'fF6m3qsD5blnwuZRuYhzWg': 256,
#  'AfWA8pvc5AW9QafQLui7_A': 256,
#  'OVU0pQ85Zf74OVgDyPFvGQ': 256,
#  '9Ep4sguv3HH_8lWyzSogjw': 256,
#  'notMxQXE3BaBAgiD-o1jgg': 256,
#  'nMHhuYan8e3cONo3PornJA': 255,
#  'Zy2vca7i9QFGRKa4m0C__A': 255,
#  'lyC2KqGiFIwct39jbdIdJg': 255,
#  'PayaNmMeZFOFeS_jo7eB8g': 255,
#  'btp0v0Qk7CmOmuMdt3aqkQ': 255,
#  'lg1BrK8zf2DVkUdbwkTkSw': 254,
#  'bB1bVvOMkfvWFVbNmRl_VA': 254,
#  'v1aLzjTphPc6IGIy9k96vg': 253,
#  'AhpzPZH3b0PGT9mVoLCQDg': 253,
#  'qGffC4h6UOTSkLhzjj59FQ': 253,
#  'j7XuypdW_w935NhjbvKPQw': 252,
#  'xxq3nX34tsqAtcsSm21rHQ': 252,
#  'LuAClnM_sUmLbFsK4ODWiw': 252,
#  'qT4w8n27RBQ_slz_FiK0CQ': 252,
#  '_5k83wy9_5NpErw7Ecgt3g': 252,
#  '1ldDbggHHgPlj3k0SpBTKQ': 252,
#  'mYuHPciSbqi2lxYpbs-LCg': 251,
#  'zehWnERkDLir0lDxxtVXPQ': 251,
#  '24V8QQWO6VaVggHdxjQQ_A': 250,
#  'UpkfQApZT5rctZicZ_ZTgw': 250,
#  '17FKJgS11HppOf00qXKEqA': 250,
#  'zmFc8M-hS4uuyY0hklIpoQ': 250,
#  'keV-NU5jaemf9L_7HDX-OA': 249,
#  'DxUn-ukNL27GOuwjnFGFKA': 249,
#  'amr-TqfnMpxmWf2RqnK_lA': 249,
#  'itFwrNtjrQL5NPMYTeD44g': 249,
#  'Fklm4Zi7nloG1SfLpnmEkA': 248,
#  'qpptyM9Dfns3AW5E_lsu6Q': 248,
#  'y6sNNP97UCSl_p2o5Wm40A': 248,
#  'UPgqmSaO5zOWNKczVwakLA': 248,
#  'CSoURupWEyuyzkjMOExKPg': 248,
#  'ML1RJdeZ7bbfMrHvJ7m99A': 248,
#  'FC4q3hJyF8oo984xoo3RMg': 248,
#  'LfKPiwth-lGmCKTxlDoV9g': 247,
#  'M0Ulu3PzwBumgOZJL-6KnQ': 247,
#  'vvMR0jgDoBA-g1XgZy8sEg': 247,
#  'u7-9OD_9qc6PDYlMk0-VcA': 247,
#  'LwTK65TMrmtjpdZRloQDwg': 247,
#  'aPdDcFXPsWVxBhaXuZcDpw': 247,
#  'Kle8p08OShKRw5zwH4R1Gg': 247,
#  'BVCDPqlHMDPLWn9EhdDXNg': 247,
#  '8MKeIqMlo6gTqBqXC0sj3A': 246,
#  'XgfKcL7eBJE9B66qoaIlJQ': 246,
#  'jgbEZzERVI4yvAAtXWW93A': 246,
#  'fjaQ3Ixkofh8xGhklUtDnA': 246,
#  'UI8iKvzhGn2qZCGIqtQqrQ': 245,
#  'KoIRdcIfh3XWxiCeV1BDmA': 245,
#  'L-uPZxooP_ziXCtRrWi8Pw': 245,
#  'qRWqgckimeoZaBaRTyV27A': 245,
#  'fWnGkLnZzv2yl3fB7xF40g': 244,
#  'lVkDZZ8sTafPlq7f1i5row': 244,
#  '0dORc6ckZw5HezR3BuSsqw': 244,
#  'N8Q2s-Snz2vL79zB3rEEug': 244,
#  'nts2OALwvyvfNh9focRZ3w': 244,
#  'cVejKU_SrdbvzIbQ4oPV0A': 244,
#  'bpGFetX8muk0GxAT3Oea3Q': 242,
#  'jqMWeYMVeqnvHNeMd772Ew': 242,
#  'zFcd_gelAUEwAvJOgiZpvg': 241,
#  'MXOdsPTLQPsQK9hUq01DWg': 241,
#  'a3VX8WpAVt29VNlGgYJxrA': 241,
#  'E4AkhjuG-DY2DTcBrkxkGg': 241,
#  'YNx5vtfjtwXZEk2kBQoA9A': 241,
#  'GmAGA39Wjv3MLT2ju5ALQQ': 241,
#  '18TUn9oiW0k0yB6lheiOvw': 240,
#  'GIGI8bJfN6HyPzmEW-QqjA': 240,
#  'glmwOs55H49Q_D8ENZtqYQ': 240,
#  'voPFKvVFm7b01xUyJixFYA': 239,
#  '-h-q6zTIdPlkz9BDP11sBg': 239,
#  'Nq7eB1wB2EArUICtiNePvQ': 239,
#  'YCCDMLcb7UW8G-o_HsWiiA': 239,
#  'AumuGuTg3HqvtwbLPi-ZCg': 239,
#  'RFqDK2b5mpasIuAzDoDdDg': 238,
#  'zOCdVUKUN3b-obT67Qjyww': 237,
#  'UL3OMN_c-NXHlyb97pDifA': 237,
#  'MLPEpxih9E8NySHbM0FSWQ': 237,
#  'HrSowDDXw71VD_d-4g7I5g': 236,
#  'pAHUC05ceak48e745i6G4g': 236,
#  'xHI3saK0sAJEHeMK4IGVvg': 236,
#  'ObnZiF99lqggVasgyGBtVA': 236,
#  'J3A5V0Hl07o_KQSI2hHf_g': 236,
#  'UVBElUlajafZDSiBK2pltw': 236,
#  'Z6aaze-cgaYKKXlpuH9LqA': 236,
#  '-PcyNcCHU8ZWwf6_PwDbUQ': 236,
#  'qNoNkF1yJctEs3t40VkX4w': 235,
#  'uCoNIQty4nPrhn_WHo110A': 235,
#  'cLojUtqkFpVIHFEvA_5Atw': 234,
#  'aSZzH68--YxNQYAO5nKBkA': 234,
#  '9VZ_imQjvgtpt3k6W6AQ_A': 234,
#  '7_zL7NX_rDFwhbLp98PwZg': 234,
#  'e9nN4XxjdHj4qtKCOPq_vg': 233,
#  'P8gXyZy1ZS7B4S20q8hzPQ': 233,
#  'QY8CBhPwv6dE4onjhj6MDg': 233,
#  'lfmvmL6iHq9-IDABLeNsuw': 232,
#  'vAOTGsBMJp2ebRCJ6Ny7NQ': 232,
#  'XkNQVTkCEzBrq7OlRHI11Q': 231,
#  'MhgYfihkb1QZfVpSNLb2uA': 231,
#  'GHSgzzzSpapvYke8MX3blg': 231,
#  'ravINrZil-a_nAl95-KjDQ': 231,
#  '2OY8xs4aqOt8eTnYokdrww': 231,
#  'XInU2SUuNK-IgnT-sEIvGA': 231,
#  'TfTlOE6h9E9o34dEkw9L_w': 230,
#  'd3MxUXS1b6U2P_gGuCO1-A': 230,
#  'mXk7cxR0OeZESz8S2q18Jw': 230,
#  'mVJIPDv-qfYlatHYeP_saQ': 230,
#  'KBG28p3lGX17hOPoHhq5PQ': 229,
#  '1MMztCZKPtw9DoCVflfZFg': 229,
#  'OvE1oiSg9gaB9cLGzBPlnw': 229,
#  'wNUea3IXZWD63bbOQaOH-g': 228,
#  '-bd26a1QEEpqUZjBmtBUiQ': 228,
#  'qw93CjlAZ6a4ff11Z-hF3Q': 228,
#  'VAeiLMTICw2CSFpy28CsWQ': 227,
#  'EIshA1evDfCTcuI0dYUo7A': 227,
#  'YZuHOgbKiP3dN4_ROOUyDQ': 226,
#  'ateowLnq6kpgNNWHzCDByQ': 226,
#  'JuBygU4XDjqSeW9okyvbsQ': 226,
#  'w19cemjVR8u02PgjFpJ7Mw': 225,
#  '9ziO3NpoNTKHvIKCBFB_fQ': 225,
#  'qpo6O2Ozbrn8wFnoCM4slA': 225,
#  '8lLkZOfXbSMumZC-v08GaA': 224,
#  'EMGkbiCMfMTflQux-_JY7Q': 224,
#  's93PtWxihLbhK5Jg_FttzA': 224,
#  '6md4A90THda31wTg1bB3hg': 224,
#  'S8O3BoCDEK-te8U-0IvZog': 223,
#  'ecpYgTTQuXzmYNGxGTvbhw': 223,
#  'X0cEpOYi0Gf-S_-xb8OZVQ': 223,
#  'soiGohHtWOltGeomkSxzEw': 222,
#  'XfVGU6WGZKc867spn2TImw': 222,
#  'UW2gLVwL3qbh9ucnb0JjyQ': 222,
#  'th4uGmjyjPnQpN-ukf20PA': 222,
#  'mU57qypB4nLScxgowHNEUA': 222,
#  'RQWliUrWic_b5FZEj3JThQ': 222,
#  'zORdAIouXrGO1yU4sIMweg': 221,
#  'EHIZFzQQ_mjzwyjcaToPtQ': 220,
#  'eltTG6JOr9cg5FRAgGy8Jw': 220,
#  'jnzROxEjNkgeo5Ju3F8qzQ': 220,
#  'cMBZ46gNJPYY7zkxDb1piw': 220,
#  'x_MCZPQ9G-IsDnwkJBceIQ': 220,
#  'LMG0zsAkUSscIvmV9vvm3A': 220,
#  'ME8gcI4BXjmFq7zEMtk3ag': 219,
#  'G9LwkTSdKOyOGqd5BbuIkA': 219,
#  'DKY2be7dDX2CT_WB_Dk4pQ': 219,
#  '9_HsCjEELmey18A-gTzZKw': 219,
#  'cQJM8VpY21O3HVu7j_b7Vw': 219,
#  'Y606ZDAYwBug3CUwgHZQZA': 218,
#  '7YYD_agS3Kb2sAx9JPkQEw': 218,
#  'jfDBaBgwINrGYAo8p2MJ4g': 218,
#  '9YUe5J_cPCBo_mL7-z9HCQ': 218,
#  '1Duul3qCnLrNak1Np-iHfw': 218,
#  'VbI_ryrGPdNRaDrYRJGMiA': 218,
#  'LHzVPddSPzMECho55zCf0Q': 218,
#  'EppRsj7YUChmu9rXb38LKg': 218,
#  '6X9iyuM2XdoCGT4q9qv5cA': 217,
#  '5ambRqdTJt9vGwFzVI9HBw': 216,
#  'SqpICnZPgxUraMDNqu-YwA': 216,
#  'R0MhNwopWTWXcg8CPAFgpw': 216,
#  '6X01fXVzhCght4ZJ9Ei2JQ': 216,
#  '8Nsh8u0zHYegI6XT1L39Lg': 216,
#  'fEX1IcPNrhJAdwk4DgyVVw': 216,
#  'DoEMzev54WS8_lVLJ3NoqQ': 216,
#  'P8DQlNd4ZVCtxFsH_QARFQ': 216,
#  'DDnmNTvIIQu2t3WZ2EQx-w': 215,
#  'Shy4HqmyEewCLvq7Ub3Whg': 215,
#  'fK7ujDbjhRFEe2D7eIwK4w': 215,
#  'h83afVKqwBlA-zOu_vdtEw': 215,
#  'xhh72bIFefOaAxsj4vJJaA': 215,
#  '2vQoWGEcSSBIJtUiGRKi5g': 215,
#  'zObyDUjiXSTCXa5t6w9ghg': 214,
#  'svoahtxi05CncY954Vu-uw': 214,
#  'bZivzFTkkjNtUBSuMhoCtg': 214,
#  'VTwL7dvXIvepNH9r9CUK8w': 214,
#  'Cu3L4mNS_Np34wD7Af2fCw': 213,
#  'hNx3bcJT3pjw2hxbLhMy8g': 213,
#  'XU5Fb3TosXDUJcNRWQM5cA': 212,
#  'V7-f6dE87cNga5dSJ4CuZw': 212,
#  'VdY6qe9afspFwsbzX1HsOQ': 212,
#  'nEY3mwbpAJlQ5FOQ-F4Giw': 212,
#  'Tt6DYs0TyERWHWW5xiRL_A': 212,
#  'riTkPznlAPl86dazAjPO3A': 211,
#  'G149aO4XXAKBsUcksvuI7g': 211,
#  '-GZsHVDlI6wvLsgD1Yaj0g': 211,
#  'qmIT3LC-kMNiOy7_XpWNUA': 211,
#  'r70nuDpkR5-g1oShW2ANvA': 210,
#  'jGldmslgIegQNM5kvb851Q': 210,
#  '3xEB9FyFXolq1b_Qn_BFtg': 210,
#  '0udEgNqy5rLR5pZ4kD19Og': 210,
#  'vbcdf7dXxfc3uyOoi7ryyA': 210,
#  'Pt5AYjhzoU93biVeVahLKw': 210,
#  'OU6yfyuCzwJZvZFRnTOZzg': 210,
#  'sNuyncpQdcvfEpfZS-3Yew': 209,
#  'oyzxIqrtzu-8sWlPhJVsLw': 209,
#  'AYbUb5UcAngroJ6uJG7tLQ': 209,
#  '9tSHBEoAhKu-tkU8n6SKjA': 209,
#  'HsAYzU2-Z_vZAaRqHbcP8g': 209,
#  'Vtx0VYkybAd71fzwgaoQ8g': 209,
#  'oQfCWtO5-fGTFrclqCJOwg': 209,
#  'ul8ViWuPb2iRez1Zd3Xw4w': 209,
#  'UO80ofDOenKF4QWR2z-oKA': 208,
#  'kR92Dbu3jwrODAhATsZ_3g': 207,
#  'd-_ZMeph2MIsCOEhKCkTbA': 207,
#  '7cP7WFmWiTVh-raIL3N_Vw': 207,
#  '40VsC3U_JLufzJ6b5GhXTg': 207,
#  'nQUsMhT7qY6pPMvTT6xGcQ': 207,
#  'Z1KDov5DRTG-rYF_6TyO1A': 206,
#  'l_qgSgZfarlgVjYy6NybPw': 206,
#  'NK-8zniVfA21IQoQCynrDg': 206,
#  'zruUQvFySeXyEd7_rQixBg': 205,
#  '-EctXOb3B7T177jGYUhjVA': 205,
#  'uyEUL3Oskfa1fOYCksyM8A': 205,
#  'XMRj865sZBPWCI7tx0uBWw': 205,
#  '-3WVw1TNQbPBzaKCaQQ1AQ': 204,
#  'IM-9thHqQbBK5tX5MfTzBQ': 204,
#  '65UBcPxX0Q1xCagf0_7w1Q': 204,
#  'lIlaoptZjY7DD4pO0Mk8ow': 204,
#  'ofhhRbEYZnmd2eKsD575nQ': 204,
#  '2Dbg35sPSGmZGcbBVNa9dA': 204,
#  't65wgP7lQrCqxjBpMwOdbw': 204,
#  'jJlOPkv4Xl6vxNzr51fnYw': 203,
#  'vaabk6CYXX1dYVQ1xkyPUg': 203,
#  'Pg8OPh1D2ws0xO-I-8ppoA': 202,
#  '9c_9SX-7hB7HW8KatQbD8g': 202,
#  'RhqrOvy6Zr8vn5pJ9PkF1A': 202,
#  'nFo_63pTr-4ZhakuaRFOCA': 202,
#  'o1GIYYZJjM6nM03fQs_uEQ': 202,
#  'mANSEm_FbXK6qtB7n6nWgg': 202,
#  'a1t31qMLd5fQocEjbSJ61A': 201,
#  'HMUvbAHRnbAczNrYy8e5MA': 201,
#  'jVgtPnzXvZQOCCIUPEBktA': 201,
#  'r-SMWki62MIjPlsSRdlBVw': 201,
#  'o1W6gwCqnJqvdCenLWz5GA': 201,
#  '6qnB6AQSur85BLx6c11dOA': 201,
#  'd4bXnfbUc1SLu3jVcr-w1w': 201,
#  '_UsqOvmgoNzb_0xWpzwZBg': 201,
#  '_WP0nIqmrSFLcY8nV8KUSA': 201,
#  'dNsKB5LA2Mf8BDqTS_FAIA': 201,
#  'lKQ5hnkSQ-XP80jNCH46nQ': 201,
#  'Vn8qcaX64fkl8vByCsSvIg': 200,
#  'x5LrBYPOFlarnDvUTouL7Q': 200,
#  'He9Dar4bk2vyeiPC7TkUgA': 200,
#  'wl51t6lT7leiX64SlkOx6g': 200,
#  't80qleqEIqIyekB95IrAOA': 200,
#  '2dioqPw6txEgB397frYg-A': 199,
#  'kfscAJnLVf6J2uEte7g-5A': 199,
#  '8MT1-gmaxyyee7kZp0a85g': 199,
#  '3MIy-ca6QVtKWXNzerQxWw': 199,
#  'AC1xogsITgaae5ic8B9Ryw': 199,
#  'MRUsPIVywMFDZHbfDa6YjA': 199,
#  'jBb5KHHAj4s8hcXVS6QXDg': 199,
#  'Exx5ffvnmk4MrTyCkPRuug': 198,
#  'RfR5yc4j9coIPBuxRsOW8Q': 198,
#  'Bjt3rB73dvSDe1XEPEWc6w': 198,
#  'Hb6n-TyLhEDdCyPyH3E3oQ': 197,
#  '1Fupq7erFi4uqC_gd9ypQg': 197,
#  'g_xxHSr7uglGfd9tXfyHkA': 197,
#  '_HTE4pOKeJC7kcxiCF9vTA': 197,
#  'wZxrcIHmkhT4OHvIxPwd_A': 197,
#  'Xnwjo2TUu4AyGdmsxeG7OQ': 197,
#  'cmf4fKU9D6XIvciQj7RjoQ': 197,
#  '0mPrp8m_caTxdSGfIxNtTw': 197,
#  'z-vuSxK4jQvRBdsk4lFCAw': 197,
#  '27ADmOieSUZfbiU15als7w': 197,
#  'Yin_BwfzTOdC8VY9ZD4K6w': 196,
#  'c0RSs2KYK5Y-ZlSrNq9LyA': 196,
#  'byhwHi0lhYdyY5kSpuqoaQ': 196,
#  'CKhtiDFAfr31jQIJrpehuw': 195,
#  'V3ruBXjLGWniPNPQOzRhiw': 195,
#  'vwZ15OkVO6PemAe87k0M-Q': 195,
#  'qgfohcxx-FH549osIz5XlQ': 195,
#  'nvaAUTTl7oqiJDhuimNG6A': 195,
#  'y8VQQO_WkYNjSLcq6hyjPA': 195,
#  'mQfT3JYu18HN22DVylcE7A': 194,
#  'BPi1Q5wX0_o5VlO_XRyYuQ': 194,
#  'nlFlIeziD-4nNUF2B337Yw': 194,
#  'gsQ1ZB3nzUCo93kqougigA': 194,
#  'H52LFxw13LBS6_ewxCwlfg': 194,
#  'TnkxapUN4nWMz_z5h3qMYg': 194,
#  'Kxp8cIMt3-vxwtCSsL9QKQ': 194,
#  '63d0v1xVzzahrY7zLoy_FA': 194,
#  'fP-BPL6iRu2tbcvlnjRshw': 193,
#  'sAbRiVqmxNdjTja_vmnsnA': 193,
#  '52QtjHlHoa7V611bOvv1aw': 193,
#  'VpW40mznMS43CqdbelX2wA': 193,
#  'uSbUk-3UcgzTPpzyL9dgJQ': 193,
#  'yXtCzVqUR6WYARQdawyevw': 193,
#  'Txg5Xo0njHL3-raZTqCNTw': 193,
#  '2nzUx_M8Szyzsf4CszHasw': 193,
#  '_AvHni-xdRHmZ3XfYHwGkg': 193,
#  'yc5AH9H71xJidA_J2mChLA': 193,
#  'pa6K7DGByxBXxcVJ59nWMw': 192,
#  '0vzZ_Bcb02rJljeMU9XkBw': 192,
#  '9IbQxDmWBG2t8w9nw9VgEA': 192,
#  '_tkAI5Q5XQSfgbqJzDKSDQ': 192,
#  'LzpR_jE6VIutJ08s2cdRrw': 192,
#  'xs1LHeJy78u-7taSEnQ2Yw': 191,
#  'TWNjTof9SeYi3I-x53MpGg': 191,
#  '_GWuXjPNBnO56OaT_daPZQ': 191,
#  'WqdCrAhYSewDAom1qY-t_g': 190,
#  'h4GmXUxM07MTOlMiGa0KuA': 190,
#  'rG_8t33D2ADcbBqcXqwV0Q': 190,
#  'Fr9OoqQplP76DsntQ-2ufg': 190,
#  'atzOrsnL_2pL6OttGbgUeA': 190,
#  'Iyy4pDmnKTZkAorzclO4Eg': 190,
#  'fVgrpVyp-nPLTac9YIjTug': 190,
#  'uLJirdITHvQLKWIW6kKoWw': 190,
#  'NfdZgoNTGsfth9MS8Qaurg': 189,
#  '8cL7aJVKTYmLguzXEAS3Lw': 189,
#  'LsArM1PhbqvXK3lDK-Ch_w': 189,
#  'ghnQrKVEjiWZ3UE1XDzJUQ': 188,
#  'muCl5p-9ut1sY0aKeUeRhw': 188,
#  'bQFhCrHnUuoB8XGllzObSA': 188,
#  'zZXLeL6fXP7LlhJ73-c20Q': 188,
#  'WCGU5Xn01lfNJG_LvEltzw': 188,
#  'c9wKRLG8MmJVdFIx9qtgfA': 188,
#  'kr3EFhoSwbJPrL_e_RD39g': 188,
#  'k6Si433-EJrY4J7SZxsnjA': 187,
#  'hdxDwMNNfclcUVYLX-cN_Q': 187,
#  'mqQwChPNN4o4DhAzaGntIA': 187,
#  '1vl4-5il_LGtDRxUCy9ldw': 187,
#  'un3KC2gyMrSG6yqjVRctXg': 186,
#  'iNvY0zAlaD_ye7Z6rHu-Ug': 186,
#  'vEeiIvhzz29rO-6EPFqkjQ': 186,
#  'TuarWzZ4ITf3H7vkPrz-Kw': 186,
#  'hVSuSlR4uYNnap2LU-6Tcg': 185,
#  'Pfb6VOIiroqDWOebfgWGPQ': 185,
#  'nU347OP_4DjBc8WLKU_J-g': 185,
#  'tdeHd2AVYlEnz9F1UGb84Q': 185,
#  'wH9WtaTlrRawH_IpK90RPg': 185,
#  'js12Ev8XKlh36gZeGHzQnA': 185,
#  'ABrSt3fsirLrUYNVrD3fbQ': 185,
#  'Crd82TFkF-cF5WF_qKuJ4A': 185,
#  '1MJ5xmHmeCiau07X2bQyUQ': 184,
#  'LOef7o-dnn7Z5qGMZCi6pw': 184,
#  '5rtC3OBCIq0WKVoKH--GCg': 184,
#  '6gJj6LSZY5HsOhaYpIvQxw': 184,
#  'WtCsHjZVF83TNTieRkFxZw': 184,
#  'bzSzpGAn4kjGRtsgMM1pvg': 184,
#  'orRee-skZXdMw0DYtMGo5w': 183,
#  'LTMEAdWM4m5tIDCSrkALIg': 183,
#  'Qher1XRFuU8GnhA4BH7wog': 183,
#  '1OA1jo0GlK9sf68f00w8ZQ': 183,
#  'xWlCgISVtozxCztPA4nGaQ': 183,
#  'qjpy8B_4J74QvfHFh1nrIg': 183,
#  'VO-OXdvcTHnhKhkNjjJDeQ': 183,
#  'oo7VmDn-qmEApGmZn2fRig': 183,
#  'UB2j_EV3CIM_E4LcpadKMQ': 183,
#  'jEWfxxA_kjeJE_Z_ku3zLA': 183,
#  'QvRK2dyv4EDxuJ-LuodE2Q': 183,
#  'iDYzGVIF1TDWdjHNgNjCVw': 183,
#  'e34tIpveepWkpvOuv_boqw': 182,
#  '5AKTjYSVTT4z_yWmTMrEXA': 182,
#  'tb24fvNJfHhyKEXkKn12Xw': 182,
#  'rEiyb2uYjaL-MrVRmndOkw': 181,
#  'EHi-lebXGWjSktl4WvSoow': 181,
#  'mwiNm868yAo8Xh8hO7Ke_Q': 181,
#  'EH7sT3dV-B365RETWCQhIA': 181,
#  'MLcXtnpzygZvQ9BtseLLlw': 180,
#  'Ni9aqkG_fNWrH02VNlRhLQ': 180,
#  'po3QfLD7vINIFtyYTgkEMQ': 180,
#  'nhToFLPoqNixNbRK4-xFQg': 180,
#  'aidjBZ-cLeRmrsAPM6ZkcA': 179,
#  '8Z3jgKCdfp57PvT1AFOWtg': 179,
#  'HOrfsgClwysVlDv1Vp7PIg': 179,
#  'aatc6tdT8rXUenDEM-L8BQ': 178,
#  'y75baZnoI51J8WS7NK9FHQ': 178,
#  'gCo--CY5aUoByxUAET2cTw': 178,
#  '81yKeu6as0NI2eIpNvgCMQ': 178,
#  'XZWry6opFKs-BIwfpa_RWg': 177,
#  'xsSnuGCCJD4OgWnOZ0zB4A': 177,
#  'Jlcx_J7DAqXthtsb_OMBEw': 177,
#  'tZXPhvufHhfejGrRp554Lg': 177,
#  'MAfc2V_EVtyR9rMxxEAPLg': 177,
#  'whJLVLRto7nVjmwk_XBV3g': 177,
#  '2lF_8RZRBd9STfk_QwAtmg': 177,
#  'KV-yJLmlODfUG1Mkds6kYw': 177,
#  'k8JnZBspVOI8kLcQek-Chw': 177,
#  'yJr24Yy1K6bt2G9fX3_zPA': 177,
#  'KIn7cdF9NCjhYF6SfFFUVQ': 176,
#  'TzImzfIWkZTnetKl2a4-SQ': 176,
#  'uBcUz2Jnqu5OzXnuAWaJew': 176,
#  'pqkwR2me0LhEZulRcQpOuw': 176,
#  'K845ZDttFfx99zQ-0aE2tA': 176,
#  'uMxfxbqT27XDeU9UTXeErg': 176,
#  '5yMcbS15CfhSvVQWCe79tw': 175,
#  'E_nRKWLMGKiCW7ft5FPYvw': 175,
#  'GbEOmf5k73r_UJWjchrHOg': 175,
#  't2QVqqi4Mjf4y1uigc9Npg': 175,
#  '9OFr3nlEDwncUNgbqFKd5w': 174,
#  'M_b7P2IBKY6zyqDmXE1kJA': 174,
#  'SkcccvAydbt5zlQI0EUL2g': 174,
#  'DlCtdbceo4YNSI53cCL2lg': 174,
#  '3wLLf8wRqD1ZQowi9aZSoA': 174,
#  '3Zsjlum5kl5N5KV712aTMQ': 173,
#  'F-ZOeAK1v7e5Rt2Mv5rVMw': 173,
#  'd8FP2gvMoeiiIa5mdn8jZg': 173,
#  'e5kc0CQ4R-PCCDgb274gSg': 173,
#  'hsTKn-6YSH3JsOSiYKGkwQ': 173,
#  '7WGBi29_vj_7RcPVxpLNHA': 173,
#  'fDZzCjlxaA4OOmnFO-i0vw': 173,
#  'q1nDSpmV-FdTBNj6UuZvTg': 173,
#  'MNop9uxBB4gVhPhHmksMkw': 173,
#  'nmj5yK9dZ2atlM9RYDCRHw': 172,
#  'kqGbGsG2p6Y3vkplCKyE9g': 172,
#  'HT-3izSFU8ZMazvSqrADyw': 172,
#  'yypKLRJxSjR2uNaTS_O6pw': 172,
#  'awchAzxp8VwNcgj5oz9WDg': 172,
#  'kePxkm183BDiOiDcsjgAhg': 172,
#  '_3f8o37w8APyUboCgwPkhA': 172,
#  'fowXs9zAM0TQhSfSkPeVuw': 171,
#  'ke4Z0EyWNoapfLnXEvheVw': 171,
#  'JsPe2EU2oP5eGyEkX1tYLw': 171,
#  'x3ws2L-TlI-JPcEQjjEC9g': 170,
#  '-VnVvJzps8QkDbc1GmHnmQ': 170,
#  'NhpdNYXoRofaa649drCz3g': 170,
#  'Xk3inJcuBGLhavUcdlINZA': 170,
#  '4OH2tMl8Qcebshi2rUTz-g': 170,
#  'B3X4Cbty1G_m9abGL47sQw': 170,
#  'NDfh7hy6k0JBYHCL93SAkA': 170,
#  'OAQoNECtxntebJ4LfLykWw': 169,
#  'MPyxaNVuWlAQqJ0iKV5rQw': 169,
#  'Az69nueCy94SVKkWaNNR0Q': 169,
#  'trC8BtTuNJniFaCaK1IQ4w': 169,
#  'sXEOGcIGsO2_zZXYxVadTw': 169,
#  'QgeyXkZKSOIS_85pDIVuQQ': 169,
#  'N2RtQLz2TiTpaMJoDoUpeA': 169,
#  'yxxLFua918P53BQADGCSCw': 169,
#  'uY1hOM4pySx07Yle9NGAiQ': 168,
#  'eXaVJc5GMIjYEUjbrc13FA': 168,
#  'lHr-aMBHh29zLpuB2ShAMQ': 168,
#  'j3xNAQtY6nFLeE6p4TpJoQ': 168,
#  'Y5GPZgCu0UeGy5NiAKC6_w': 168,
#  'RtwOc-n_RkiUuDGaNfCsNw': 168,
#  'Nw8lWJRGybAsciao9h-R2Q': 168,
#  'guLkdetJ603Bw_A6tuecIg': 168,
#  'rXEGCpdboVwczMIDZuXXaA': 167,
#  'KBKDl08flVw1AqvM5ucVpA': 167,
#  'kwD6P2-EV87u6aVOcnAcpQ': 167,
#  'cT_rocMh92B9t62Disp6gA': 167,
#  'Je396Ev-dvAvl3ei-O0EIg': 167,
#  'pzPbg_B2uSVJ72LIa2G3sA': 167,
#  'pF7uRzygyZsltbmVpjIyvw': 167,
#  'dl5K9Hc2kUcGcrVIQAOhWQ': 167,
#  'A-wbnt6g19IWirBswkzsig': 166,
#  'ZFAq9lpm2wXihzvMLSsRJQ': 166,
#  'lzoTXcynmfZ6Ler5B4HbfQ': 166,
#  'jiWAo2z_seY5pQwhzrJiYA': 165,
#  '4h8_u6Fqm3JvUEq8ctWf-A': 165,
#  'N_LG7wMjLSOJ9mgBr1kWtA': 165,
#  'FY_OXEVcewAQFZuu6fynLA': 165,
#  'jSDLdzm7ZbMWL3g3D2GU9w': 165,
#  'CU5d1QN2A5cgcR9zmLVS0g': 165,
#  'mgN7A6Uw8ObmoTNZvx6VOg': 165,
#  'q9WaFYhlOZCrfXJQTG5t_Q': 165,
#  'kK4AzZ0YWI-U2G-paAL7Fg': 165,
#  'Q9KILetOPQLzIf7Ki3D8-g': 165,
#  '9AbyBqGWHYZC73GlyAuTrQ': 164,
#  '2KCHbRLC2e9b2tiFN5Gxww': 164,
#  'a1aIYuvQUdSFOyn4vKIXnA': 164,
#  'NAkRjPhS4yCD5trp0dY-bQ': 164,
#  'fjRBF1-0JlJoxH5_jDANgA': 164,
#  '1sNa5oW9ZYX8MbMFkx9LzQ': 164,
#  'Hgbxen9iKGL4AH6kKgC8YQ': 164,
#  'rrWhi2TL0smrbihvavZxcg': 164,
#  'IMGW6y8wHQCfr_6k-YXg_A': 163,
#  'UWPQelWfvXOFpFQXTsVzow': 163,
#  'R6aazv8FB-6BeanY3ag8kw': 163,
#  'yJMLD-6AggZNdC-GonVBsA': 163,
#  'JRzrqJmsQ5AZ4bMQLUfyHg': 163,
#  'gEAB85-Zcm8Qs5JQPC_PHg': 163,
#  '5SS69rC8XWvdlD1OHifEEQ': 163,
#  'Xmcr6VtUk_01fTwkTKrrQw': 163,
#  'JkuXXDySMl5fF0hwmLxNCA': 163,
#  'hGQsnkndreW7b26XC2HVRA': 163,
#  'cInzGnaFZ3EIItvFXl1MvQ': 162,
#  '5-X03Zc0nN7U5eoe8uFUdw': 162,
#  'A71fIjJHDvnOFYeL_Jkv7A': 162,
#  '3nwskbfFgsSjVe6T8keTeg': 162,
#  'zj0BkAi54BGU_AK6AyvJDQ': 162,
#  '-gefwOTDqW9HWGDvWBPSMQ': 162,
#  '0InQd9vuhRc98OksC3Ks8Q': 162,
#  '8zTes4kUSoM161AD7G6DsQ': 161,
#  'ImJ7QAw6T6ayJT1AGr7OgA': 161,
#  'B_aOu7idHDU7_5t5RNuydA': 161,
#  'mbpDk_uvYwH2ZPo8LoJYxg': 161,
#  'o_w69y1M6pkKetd1w43i_w': 161,
#  'Cp6JGY5YIRncTV_My9nf9g': 161,
#  'WEKQZap6YHcU25b6kIypNg': 161,
#  'JMOK_Sy6aSOZwd4qgkX7hg': 161,
#  'SK77jbqCpIv_lwwRkhq9_w': 160,
#  'qlrZzAktK8wODSHxhLEK7w': 160,
#  '15srJBiBZBt0iKsWSABwRg': 160,
#  'pU8beAibeYjH5-KTsJqVYg': 160,
#  '2bdKR3l4o-S1CscLqqnvVw': 160,
#  '3AMFoTdFm7j2bocSpm7Xxw': 160,
#  '4KwEzJyeuHqna7_A_eeI3g': 160,
#  'svx5Gw-FJ6ZU9hb58aXgLg': 160,
#  'lVHtVCyFJOqAH0ltn7pLuw': 159,
#  'wL-h9AXEEMlc8A1Alo9vhg': 159,
#  'YldXB1hRpnE1CWLF3mvgpQ': 159,
#  'P5a2hK5G64J7DcNwLAPhuA': 159,
#  '9yKzy9PApeiPPOUJEtnvkg': 159,
#  'KTF-E3NfkJy2wiwcgOPyVQ': 159,
#  'GAPqG0WNBBidKeZTMpEZ-w': 159,
#  'T4ox3wUzFjWvyrjaTRoBbA': 159,
#  'F8ljll9IJhgUmOxUshlqiQ': 159,
#  '9Qt1pt0pk2VWz0chdGk-jw': 158,
#  'kK_8YUQlBX8l05eblLgBeg': 158,
#  'Rzg2-ugIG_UxQCN_JqXDcA': 158,
#  'CVos739DJ06t8-dNiRMyeQ': 158,
#  '6svqiMcmS-tolyzsz2S4-Q': 158,
#  'ZCkh7L0HyZ8L9RclT7A_cw': 158,
#  'cdwHgELA2puX2DNfwSt5EA': 158,
#  'OBUbR8vRZ7RmotiwvBlVDg': 158,
#  'DoLjiU_CSHcKFkofAsUg8A': 158,
#  'gPmoQaWDiVnkUWOHY-TYOQ': 158,
#  'cJbaH81HP6r0eHDy8_738Q': 157,
#  'URweBWkD1EgPDFUlL0LOKQ': 157,
#  '1M4oczf2lmkdgbrJ3J7OqA': 157,
#  'UScgPn6pIHuOmQJTsZQIOg': 157,
#  'IC8no-tIdDWgkYzb5d-Nvw': 157,
#  'hyff2JyqQgf85MaJZslHCg': 157,
#  'vQo_kFaVjVa9H_nhRCz-Dw': 157,
#  'HZjLErXWi1vZWMgsAjBEeQ': 157,
#  'A_vRqMo7HrlnCRFvzWVcfw': 157,
#  'TuuENwzxOFdDLY_oKCbFZw': 157,
#  'DW6SI2KxcfXBHeo9jEr4lQ': 156,
#  's8cHXeSlX_aPI2x49UkCCg': 156,
#  'r4AG1WXCRWkZKQctrcy9FA': 156,
#  'rO3saNBRU2Pg16RyfEP6-g': 156,
#  '9qDxlEmzsp_-_PTwBu6maw': 156,
#  'YxQ1ssiSvjmprGHKygKfcg': 156,
#  '3gxFy26l-1_s30Itk0OAYA': 156,
#  'zBacxYJdcxmJETelXMt9aw': 156,
#  'pfTwzep_4hRTX_jXoi38cw': 155,
#  'QeQQon7GReMtjQiqKgln_w': 155,
#  '8o-NLKy_XfbJtqljX9XLCA': 155,
#  '1MQmujTuU-3qPdoogdA8CQ': 155,
#  'gVYju3XRcO1R4aNk7SZJcA': 155,
#  'IdnYOlL9aDfMu_S2kcaUkQ': 155,
#  'TuCAYZ89lP_s6D7Y78xNhQ': 155,
#  'n_d7HDsTdLc9IWwuPHBNlg': 155,
#  'gWRJ_Zyl2gtx_pCNTKnG2A': 155,
#  'KGX7O-_WqOIy9o7u9NOa9A': 154,
#  'iDQK85-DyIlSpTz_XhkZVA': 154,
#  'ilJiRYZgxjrEu2iexKu-pQ': 154,
#  'H2pm7yVZci7M5RKhAOYzuA': 154,
#  'znmvCpcwxYk_kYCqtUFt5Q': 154,
#  'L_MtTn4IUBTmQtqqM2iFqA': 154,
#  'bKcmSucAGlKHwwVZNvhI3w': 154,
#  'OllL0G9Kh_k1lx-2vrFDXQ': 154,
#  '9CLZ-Uwv3nmOlbbGCIhvrQ': 154,
#  '0db71MbrvcJnyk71COCJBg': 154,
#  'RmA5zN-Bs89lsTuY6v8W3Q': 153,
#  'KleJUKZjGFFhybrcpZIyHQ': 153,
#  'qwmHm3s8p7J12AIY6Co8HQ': 153,
#  'DHk8is9rvfnATsW1AudWQg': 153,
#  'T-D-YoUQlttcF9a2ZyOxfA': 153,
#  'ZRJwVLyzEJq1VAihDhYiow': 153,
#  'ckliJ8meY4ZMF6aQUb8PYw': 153,
#  'N_6bV3c3JagKW7sD3X9ldA': 153,
#  'oJpmYvLibGrYPDvcaUeMOw': 153,
#  'mhLN_oiJd7zq6eaOS1Nw1A': 153,
#  'Lbue8gqRiBPEnA7g7H1qdw': 152,
#  'YnWb8fRudnNkXc-VjrmKGg': 152,
#  'xOy3lZcDvGp40BI5x-PR9w': 152,
#  ...}

# %% [markdown]
# So we see some places have over 3000 reviews and some places only have 1 (and some unlisted have none!) so we'll kick out the ones that have less than 5 and see what happens.

# %%
good_ones = []
cutoff = 1000

for key in review_counts.keys():
    if review_counts[key]>cutoff:
        good_ones.append(key)
        
len(good_ones)
# Out:
# 32

# %%
restaurant_reviews_df = restaurant_reviews_df.loc[restaurant_reviews_df['business_id'].isin(good_ones)]
restaurant_reviews_df.shape
# Out:
# (53222, 8)

# %% [markdown]
# That's not much of a decrease :(

# %% [markdown]
# ## Cleaning the Data
#
# So we have a lot of reviews to look at (> 1 million!) and we only really care about the text column for now. The next step is to clean the data. In this instance we are going to remove the punctuation and convert all to lowercase.

# %%
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Convert all to lowercase
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char.lower() for char in mess if char not in punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    return nopunc

# %%
restaurant_reviews_df['text_clean'] = restaurant_reviews_df['text'].apply(text_process)
restaurant_reviews_df.head()
# Out:
#                   business_id       date               review_id  stars  \
# 99644  FV16IeXJp2W6pnghTz2FAw 2007-01-02  aH8o5WZ6mAu3FKEqUm9aDg      4
# 99645  FV16IeXJp2W6pnghTz2FAw 2007-01-07  6WG0bt9wew39wmdyCoFteQ      4
# 99646  FV16IeXJp2W6pnghTz2FAw 2007-01-13  s6dt4gwoqV-0B_TOljcWEA      4
# 99647  FV16IeXJp2W6pnghTz2FAw 2007-01-24  7EPKJm7bB6EsW0Ke0lRWKg      4
# 99648  FV16IeXJp2W6pnghTz2FAw 2007-01-30  EFIVGXez5b9k43865kgJKg      4
#
#                                                     text    type  \
# 99644  Me and la familia ate here 3 times over my 3 n...  review
# 99645  When we went to Vegas for New Year's, some peo...  review
# 99646  I'm giving it 3 stars because I only like 3 it...  review
# 99647  I have to be honest, the first time I ate hear...  review
# 99648  Dirty name, great pho!  A wonderful choice on ...  review
#
#                       user_id                                 votes  \
# 99644  sCU3KOdf_E1X1THWjhhxDw  {'funny': 1, 'useful': 1, 'cool': 1}
# 99645  YyPncV7fwWflne10BiCf6Q  {'funny': 1, 'useful': 2, 'cool': 2}
# 99646  C6wyE9k2vjpU4tIGsbN7Ww  {'funny': 0, 'useful': 0, 'cool': 0}
# 99647  7Oj_nlhwmUoTQGSLegMCdQ  {'funny': 0, 'useful': 0, 'cool': 0}
# 99648  R-2GWjkuiCyFojQZ5cmvIw  {'funny': 1, 'useful': 1, 'cool': 0}
#
#                                               text_clean
# 99644  me and la familia ate here 3 times over my 3 n...
# 99645  when we went to vegas for new years some peopl...
# 99646  im giving it 3 stars because i only like 3 ite...
# 99647  i have to be honest the first time i ate hear ...
# 99648  dirty name great pho  a wonderful choice on ch...

# %% [markdown]
# Since we only care about the text column, we will pull that out into a list

# %%
reviews = list(restaurant_reviews_df['text_clean'])
reviews[0]
# Out:
# 'me and la familia ate here 3 times over my 3 nights stay over christmas  i think i wont be missing pho for a good couple of months i lovee the pho soup and i heard the entrees are pretty damn good too especially the clams and oysters the only reasons for the 4 stars are the service and the ventilation i always come out smelling like pho which i dont like i like my hair to smell flowery u know'

# %% [markdown]
# Now's the hard part. We want to use LDA to extract topics from the review text to understand what people have talked about in these reviews. First we want to vectorize the documents.

# %% [markdown]
# # 1.1:Topic Modelling
#
# Use a topic model (e.g., PLSA or LDA) to extract topics from all the review text (or a large sample of them) and visualize the topics to understand what people have talked about in these reviews.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(stop_words='english')
tf = tf_vectorizer.fit_transform(reviews)
tf_feature_names = tf_vectorizer.get_feature_names()
tf_feature_names[0:10]
# Out:
# ['00', '000', '0000', '003100', '006', '00pm', '01', '010', '010407', '0110']

# %% [markdown]
# Well that suggests that some reviews have some weird numbers in them. Oh well. Now to build the LDA model. LDA requires some prior knowledge on the number of topics.

# %%
no_topics=7
lda_model = LatentDirichletAllocation(n_components=no_topics, learning_method='online').fit(tf)
lda_W = lda_model.transform(tf)
lda_H = lda_model.components_

# %%
def display_topics(H, W, feature_names, documents, no_top_words):
    all_topics = []
    print("\n\nLDA Topics \n\n")
    for topic_idx, topic in enumerate(H):
        print("Topic %d:" % (topic_idx))
        topics = [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]
        all_topics.append(topics)
        print(" ".join(topics)) 
        
    return all_topics

# %%
no_top_words = 15
lda_clusters = display_topics(lda_H, lda_W, tf_feature_names, reviews, no_top_words)
# Out:
# LDA Topics
#
#
# Topic 0:
# table wait food minutes time service came seated got server ordered restaurant took order asked
# Topic 1:
# burger fries sandwich ordered good chicken cheese burgers great french delicious bacon sweet bread place
# Topic 2:
# great ramen steak vegas best amazing service restaurant delicious excellent bouchon wine making meal perfect
# Topic 3:
# pizza burger gordon beer secret burgers bachi burgr fez serendipity bar bun ramsay holsteins best
# Topic 4:
# buffet food vegas good great place best line buffets breakfast worth quality selection price legs
# Topic 5:
# dessert crab good shrimp cream sauce seafood salad ice like cheese pork dishes fresh dish
# Topic 6:
# good just like place food really dont time im pretty didnt try think got wasnt

# %% [markdown]
# Now we want the data in a nice d3-friendly format for a radial dendrogam :). I want an array of objects, with each top_word coneected by a ".".

# %%
d3_array = [{'id':'Most Reviewed Yelp Restaurants'},]
count = 0

for topic in lda_clusters:
    first = {"id":'Most Reviewed Yelp Restaurants.Topic '+str(count)}
    d3_array.append(first)
    
    for word in topic:
        element = {"id":'Most Reviewed Yelp Restaurants.Topic '+str(count)+'.'+word}
        d3_array.append(element)
    
    count += 1
    
d3_array
# Out:
# [{'id': 'Most Reviewed Yelp Restaurants'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.table'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.wait'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.food'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.minutes'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.time'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.service'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.came'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.seated'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.got'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.server'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.ordered'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.restaurant'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.took'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.order'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 0.asked'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.burger'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.fries'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.sandwich'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.ordered'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.good'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.chicken'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.cheese'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.burgers'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.great'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.french'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.delicious'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.bacon'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.sweet'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.bread'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 1.place'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.great'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.ramen'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.steak'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.vegas'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.best'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.amazing'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.service'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.restaurant'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.delicious'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.excellent'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.bouchon'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.wine'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.making'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.meal'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 2.perfect'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.pizza'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.burger'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.gordon'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.beer'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.secret'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.burgers'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.bachi'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.burgr'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.fez'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.serendipity'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.bar'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.bun'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.ramsay'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.holsteins'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 3.best'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.buffet'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.food'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.vegas'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.good'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.great'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.place'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.best'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.line'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.buffets'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.breakfast'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.worth'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.quality'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.selection'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.price'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 4.legs'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.dessert'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.crab'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.good'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.shrimp'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.cream'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.sauce'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.seafood'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.salad'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.ice'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.like'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.cheese'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.pork'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.dishes'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.fresh'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 5.dish'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.good'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.just'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.like'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.place'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.food'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.really'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.dont'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.time'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.im'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.pretty'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.didnt'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.try'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.think'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.got'},
#  {'id': 'Most Reviewed Yelp Restaurants.Topic 6.wasnt'}]

# %%
with open('task1topics.txt', 'w') as f:
    for x in d3_array:
        f.write('{}\n'.format(x))

# %% [markdown]
# # Task 1.2
# Do the same for two subsets of reviews that are interesting to compare (e.g., positive vs. negative reviews for a particular cuisine or restaurant), and visually compare the topics extracted from the two subsets to help understand the similarity and differences between these topics extracted from the two subsets.
#
# ## High and low ratings
# I want to look at the different words used in high and low rating reviews. Let's see how to do this without being too overwhelmed. Let's use the same dataframe and see the spread of ratings we have.

# %%
# review_counts = dict(restaurant_reviews_df.business_id.value_counts())
# review_counts
restaurant_reviews_df.stars.value_counts()
# Out:
# 5    19919
# 4    18671
# 3     8220
# 2     4118
# 1     2294
# Name: stars, dtype: int64

# %% [markdown]
# So as expected there are many more good reviews than bad ones. Since we have so much good reviews, I'll define a good review as 5 stars, and bad reviews as ones with less than 3 stars. I'm going to have two arrays now.

# %%
good_reviews_df = restaurant_reviews_df.loc[restaurant_reviews_df['stars'] == 5]
good_reviews = list(good_reviews_df['text_clean'])
bad_reviews_df = restaurant_reviews_df.loc[restaurant_reviews_df['stars'] < 3]
bad_reviews = list(bad_reviews_df['text_clean'])
len(good_reviews)
# Out:
# 19919

# %%
tf_vectorizer = CountVectorizer(stop_words='english')
tf = tf_vectorizer.fit_transform(good_reviews)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics=5
lda_model = LatentDirichletAllocation(n_components=no_topics, learning_method='online').fit(tf)
lda_W = lda_model.transform(tf)
lda_H = lda_model.components_

no_top_words = 15
good_review_topics = display_topics(lda_H, lda_W, tf_feature_names, good_reviews, no_top_words)
# Out:
# LDA Topics
#
#
# Topic 0:
# burger fries cheese ordered steak good chicken delicious beef sweet amazing bacon sauce cream came
# Topic 1:
# place food good vegas great just time like love really best wait sandwich service delicious
# Topic 2:
# buffet food vegas best good great worth wait buffets time burger place quality ive went
# Topic 3:
# crab like rib shrimp ramen sushi buffet dishes dessert thai prime seafood food fresh good
# Topic 4:
# pizza bouchon secret crust mon ami gabi floor white bobby bianco hallway flay thomas pizzeria

# %%
tf_vectorizer = CountVectorizer(stop_words='english')
tf = tf_vectorizer.fit_transform(bad_reviews)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics=5
lda_model = LatentDirichletAllocation(n_components=no_topics, learning_method='online').fit(tf)
lda_W = lda_model.transform(tf)
lda_H = lda_model.components_

no_top_words = 15
bad_review_topics = display_topics(lda_H, lda_W, tf_feature_names, bad_reviews, no_top_words)
# Out:
# LDA Topics
#
#
# Topic 0:
# buffet crab buffets sushi legs food rib seafood selection prime good wynn dessert shrimp station
# Topic 1:
# burger good ordered like just food fries chicken hot chocolate really place got came didnt
# Topic 2:
# island ellis dogs yea earl tourists neon karaoke episode serendipity fez pack duke chutney chantrelles
# Topic 3:
# minutes table service food time order asked server came told restaurant seated took said wait
# Topic 4:
# food place good just like dont vegas time really wait line service better im people

# %%
good_d3_array = [{'id':'Most Reviewed Yelp Restaurants.5 Star Reviews', "value":5},]
count = 0

for topic in good_review_topics:
    first = {"id":'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic '+str(count), "value":5}
    good_d3_array.append(first)
    
    for word in topic:
        element = {"id":'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic '+str(count)+'.'+word, "value":5}
        good_d3_array.append(element)
    
    count += 1
    
good_d3_array
# Out:
# [{'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews', 'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0', 'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.burger',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.fries',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.cheese',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.ordered',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.steak',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.good',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.chicken',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.delicious',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.beef',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.sweet',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.amazing',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.bacon',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.sauce',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.cream',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 0.came',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1', 'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.place',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.food',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.good',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.vegas',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.great',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.just',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.time',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.like',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.love',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.really',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.best',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.wait',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.sandwich',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.service',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 1.delicious',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2', 'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.buffet',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.food',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.vegas',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.best',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.good',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.great',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.worth',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.wait',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.buffets',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.time',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.burger',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.place',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.quality',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.ive',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 2.went',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3', 'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.crab',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.like',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.rib',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.shrimp',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.ramen',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.sushi',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.buffet',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.dishes',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.dessert',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.thai',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.prime',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.seafood',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.food',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.fresh',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 3.good',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4', 'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.pizza',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.bouchon',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.secret',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.crust',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.mon',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.ami',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.gabi',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.floor',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.white',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.bobby',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.bianco',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.hallway',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.flay',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.thomas',
#   'value': 5},
#  {'id': 'Most Reviewed Yelp Restaurants.5 Star Reviews.Topic 4.pizzeria',
#   'value': 5}]

# %%
bad_d3_array = [{'id':'Most Reviewed Yelp Restaurants.1 Star Reviews', "value":1},]
count = 0

for topic in bad_review_topics:
    first = {"id":'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic '+str(count), "value":1}
    bad_d3_array.append(first)
    
    for word in topic:
        element = {"id":'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic '+str(count)+'.'+word, "value":1}
        bad_d3_array.append(element)
    
    count += 1
    
bad_d3_array
# Out:
# [{'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews', 'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0', 'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.buffet',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.crab',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.buffets',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.sushi',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.legs',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.food',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.rib',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.seafood',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.selection',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.prime',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.good',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.wynn',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.dessert',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.shrimp',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 0.station',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1', 'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.burger',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.good',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.ordered',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.like',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.just',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.food',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.fries',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.chicken',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.hot',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.chocolate',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.really',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.place',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.got',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.came',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 1.didnt',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2', 'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.island',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.ellis',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.dogs',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.yea',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.earl',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.tourists',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.neon',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.karaoke',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.episode',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.serendipity',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.fez',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.pack',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.duke',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.chutney',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 2.chantrelles',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3', 'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.minutes',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.table',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.service',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.food',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.time',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.order',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.asked',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.server',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.came',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.told',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.restaurant',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.seated',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.took',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.said',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 3.wait',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4', 'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.food',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.place',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.good',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.just',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.like',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.dont',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.vegas',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.time',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.really',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.wait',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.line',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.service',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.better',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.im',
#   'value': 1},
#  {'id': 'Most Reviewed Yelp Restaurants.1 Star Reviews.Topic 4.people',
#   'value': 1}]
